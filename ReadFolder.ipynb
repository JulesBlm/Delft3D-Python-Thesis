# %% [markdown]
# # Read complete d3d folder

# %%
from JulesD3D.D3DModel import D3DModel

# %%
folderpath = "/Users/julesblom/Dropbox/TU/Master/Thesis/Runs/Current/Final_ResetEvery5/Run01/"

model = D3DModel(folderpath)
# Out:
# D3D model filenames
#                 type                    filename
# 0  B.C. Constituents                 5050_15.bcc
# 1              Depth          gen_36_by_26km.dep
# 2                MDF    36km_200m_W60Channel.mdf
# 3           Boundary           QChannelZdeep.bnd
# 4               Grid    36km_26km_W60Channel.grd
# 5          Enclosure  36km_1cellchannel_15km.enc
# 6         Morphology                   20_20.mor
# 7          Sediments                SandSilt.sed
# 8   B.C. Time series           discharge4500.bct
# Boundary file
#          name type forcing  m1   n1   m2   n2  reflection coefficient  \
# 0  Boundaries    Q       T  66    1   66    1                   200.0
# 1  Boundaries    Z       T   2  182  131  182                   200.0
#
#   vertical profile  label1  label2
# 0       3d-profile     NaN     NaN
# 1              NaN     NaN     NaN
# Enclosure values
#      x    y
# 0    1   75
# 1   64   75
# 2   64    1
# 3   69    1
# 4   69   75
# 5  132   75
# ...

# %%
model.plotDepthPyVista()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x11D44AF90>
